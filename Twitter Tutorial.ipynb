# %% [markdown]
# # Scraping Twitter with Python
#
# There are a number different python libraries we could use, but for this example we will be using twython. The library contains convient methods to interact with twitters restful api.
# [Twython Documentation](https://twython.readthedocs.io/en/latest/index.html)
# [Twitter API Documentation](https://dev.twitter.com/rest/public)

# %% [markdown]
# #### Import packages

# %%
from twython import Twython
import json
import pytz
from datetime import datetime

# %% [markdown]
# #### Authentication
# This logs you in to you app and lets twitter keep track of you. You cannot use the api without authenticating. One reason twitter requires authentication is so that they can limit the number of requests you make in a given time period. If you are queerying a high volume of data, you will need to account for this limitation.
# Readabout it [here](https://dev.twitter.com/rest/public/rate-limiting)
#
# First, you need to create api keys to access , you can do this [here](https://apps.twitter.com). Then, you need to copy the app keys you created on twitters website into the variables below.

# %%
APP_KEY = "your_app_key" 
APP_SECRET = "your_secret_key"

# %%
twitter = Twython(APP_KEY, APP_SECRET,oauth_version=2)
ACCESS_TOKEN = twitter.obtain_access_token()
twitter = Twython(APP_KEY, access_token=ACCESS_TOKEN)

# %% [markdown]
# #### Querying the garden hose

# %%
results = twitter.search(q="sports")

# %%
results.keys()
# Out:
# [u'search_metadata', u'statuses']

# %%
tweets=[]
for result in results["statuses"]:
    tweets.append(result)

# %%
len(tweets)
# Out:
# 15

# %%
tweets
# Out:
# [{u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Thu Oct 27 21:05:50 +0000 2016',
#   u'entities': {u'hashtags': [],
#    u'symbols': [],
#    u'urls': [{u'display_url': u'vine.co/v/MrTlImjlai1',
#      u'expanded_url': u'https://vine.co/v/MrTlImjlai1',
#      u'indices': [55, 78],
#      u'url': u'https://t.co/VCSA5epUpK'}],
#    u'user_mentions': [{u'id': 498177610,
#      u'id_str': u'498177610',
#      u'indices': [3, 16],
#      u'name': u'Best Vines',
#      u'screen_name': u'TheFunnyVine'}]},
#   u'favorite_count': 0,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 791747760252973057,
#   u'id_str': u'791747760252973057',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'is_quote_status': False,
#   u'lang': u'en',
#   u'metadata': {u'iso_language_code': u'en', u'result_type': u'recent'},
#   u'place': None,
#   u'possibly_sensitive': False,
#   u'retweet_count': 893,
#   u'retweeted': False,
#   u'retweeted_status': {u'contributors': None,
#    u'coordinates': None,
#    u'created_at': u'Thu Oct 27 19:15:23 +0000 2016',
#    u'entities': {u'hashtags': [],
#     u'symbols': [],
#     u'urls': [{u'display_url': u'vine.co/v/MrTlImjlai1',
#       u'expanded_url': u'https://vine.co/v/MrTlImjlai1',
#       u'indices': [37, 60],
#       u'url': u'https://t.co/VCSA5epUpK'}],
#     u'user_mentions': []},
#    u'favorite_count': 1371,
#    u'favorited': False,
#    u'geo': None,
#    u'id': 791719962922610689,
#    u'id_str': u'791719962922610689',
#    u'in_reply_to_screen_name': None,
#    u'in_reply_to_status_id': None,
#    u'in_reply_to_status_id_str': None,
#    u'in_reply_to_user_id': None,
#    u'in_reply_to_user_id_str': None,
#    u'is_quote_status': False,
#    u'lang': u'en',
#    u'metadata': {u'iso_language_code': u'en', u'result_type': u'recent'},
#    u'place': None,
#    u'possibly_sensitive': False,
#    u'retweet_count': 893,
#    u'retweeted': False,
#    u'source': u'<a href="http://www.tweetcaster.com" rel="nofollow">TweetCaster for Android</a>',
#    u'text': u'the greatest sports vine of all time https://t.co/VCSA5epUpK',
#    u'truncated': False,
#    u'user': {u'contributors_enabled': False,
#     u'created_at': u'Mon Feb 20 19:31:53 +0000 2012',
#     u'default_profile': False,
#     u'default_profile_image': False,
#     u'description': u'We post all the best Vines. Not Affiliated With Vine! Facebook: @thefunnyvine Instagram: @the.Funny.vine Contact: thefunnyvine@gmail.com',
#     u'entities': {u'description': {u'urls': []}},
#     u'favourites_count': 8,
#     u'follow_request_sent': None,
#     u'followers_count': 1373391,
#     u'following': None,
#     u'friends_count': 10,
#     u'geo_enabled': False,
#     u'has_extended_profile': False,
#     u'id': 498177610,
#     u'id_str': u'498177610',
#     u'is_translation_enabled': False,
#     u'is_translator': False,
#     u'lang': u'en',
#     u'listed_count': 1588,
#     u'location': u'',
#     u'name': u'Best Vines',
#     u'notifications': None,
#     u'profile_background_color': u'1A1B1F',
#     u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/863599808/8409a6c3f97da1e08d2c670b2e83331f.jpeg',
#     u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/863599808/8409a6c3f97da1e08d2c670b2e83331f.jpeg',
#     u'profile_background_tile': True,
#     u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/498177610/1431213460',
#     u'profile_image_url': u'http://pbs.twimg.com/profile_images/597184401873772544/lc28AVX7_normal.png',
#     u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/597184401873772544/lc28AVX7_normal.png',
#     u'profile_link_color': u'2FC2EF',
#     u'profile_sidebar_border_color': u'FFFFFF',
#     u'profile_sidebar_fill_color': u'252429',
#     u'profile_text_color': u'666666',
#     u'profile_use_background_image': True,
#     u'protected': False,
#     u'screen_name': u'TheFunnyVine',
#     u'statuses_count': 12122,
#     u'time_zone': u'Eastern Time (US & Canada)',
#     u'translator_type': u'none',
#     u'url': None,
#     u'utc_offset': -14400,
#     u'verified': False}},
#   u'source': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   u'text': u'RT @TheFunnyVine: the greatest sports vine of all time https://t.co/VCSA5epUpK',
#   u'truncated': False,
#   u'user': {u'contributors_enabled': False,
#    u'created_at': u'Fri Jun 21 23:55:01 +0000 2013',
#    u'default_profile': False,
#    u'default_profile_image': False,
#    u'description': u'\U0001f1f2\U0001f1fd',
#    u'entities': {u'description': {u'urls': []}},
#    u'favourites_count': 429,
#    u'follow_request_sent': None,
#    u'followers_count': 41,
#    u'following': None,
#    u'friends_count': 62,
#    u'geo_enabled': True,
#    u'has_extended_profile': False,
#    u'id': 1537548450,
#    u'id_str': u'1537548450',
#    u'is_translation_enabled': False,
#    u'is_translator': False,
#    u'lang': u'fr',
#    u'listed_count': 5,
#    u'location': u'Paris',
#    u'name': u'kats_mama\u26a1\ufe0f',
#    u'notifications': None,
#    u'profile_background_color': u'000000',
#    u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme1/bg.png',
#    u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme1/bg.png',
#    u'profile_background_tile': False,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/1537548450/1466223381',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/790710732526682112/4hEl78Uo_normal.jpg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/790710732526682112/4hEl78Uo_normal.jpg',
#    u'profile_link_color': u'9266CC',
#    u'profile_sidebar_border_color': u'000000',
#    u'profile_sidebar_fill_color': u'000000',
#    u'profile_text_color': u'000000',
#    u'profile_use_background_image': False,
#    u'protected': False,
#    u'screen_name': u'Gw3nLg',
#    u'statuses_count': 850,
#    u'time_zone': None,
#    u'translator_type': u'none',
#    u'url': None,
#    u'utc_offset': None,
#    u'verified': False}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Thu Oct 27 21:05:50 +0000 2016',
#   u'entities': {u'hashtags': [],
#    u'media': [{u'display_url': u'pic.twitter.com/4zhlQGjWMh',
#      u'expanded_url': u'https://twitter.com/VarsityAces/status/791488212292304896/photo/1',
#      u'id': 791488202620239874,
#      u'id_str': u'791488202620239874',
#      u'indices': [85, 108],
#      u'media_url': u'http://pbs.twimg.com/media/CvvuU6kXgAIWBVu.jpg',
#      u'media_url_https': u'https://pbs.twimg.com/media/CvvuU6kXgAIWBVu.jpg',
#      u'sizes': {u'large': {u'h': 773, u'resize': u'fit', u'w': 1000},
#       u'medium': {u'h': 773, u'resize': u'fit', u'w': 1000},
#       u'small': {u'h': 526, u'resize': u'fit', u'w': 680},
#       u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}},
#      u'source_status_id': 791488212292304896,
#      u'source_status_id_str': u'791488212292304896',
#      u'source_user_id': 44135317,
#      u'source_user_id_str': u'44135317',
#      u'type': u'photo',
#      u'url': u'https://t.co/4zhlQGjWMh'}],
#    u'symbols': [],
#    u'urls': [{u'display_url': u'bit.ly/2ed82S7',
#      u'expanded_url': u'http://bit.ly/2ed82S7',
#      u'indices': [61, 84],
#      u'url': u'https://t.co/Q8vANHPYAe'}],
#    u'user_mentions': [{u'id': 44135317,
#      u'id_str': u'44135317',
#      u'indices': [3, 15],
#      u'name': u'Varsity Aces',
#      u'screen_name': u'VarsityAces'}]},
#   u'extended_entities': {u'media': [{u'display_url': u'pic.twitter.com/4zhlQGjWMh',
#      u'expanded_url': u'https://twitter.com/VarsityAces/status/791488212292304896/photo/1',
#      u'id': 791488202620239874,
#      u'id_str': u'791488202620239874',
#      u'indices': [85, 108],
#      u'media_url': u'http://pbs.twimg.com/media/CvvuU6kXgAIWBVu.jpg',
#      u'media_url_https': u'https://pbs.twimg.com/media/CvvuU6kXgAIWBVu.jpg',
#      u'sizes': {u'large': {u'h': 773, u'resize': u'fit', u'w': 1000},
#       u'medium': {u'h': 773, u'resize': u'fit', u'w': 1000},
#       u'small': {u'h': 526, u'resize': u'fit', u'w': 680},
#       u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}},
#      u'source_status_id': 791488212292304896,
#      u'source_status_id_str': u'791488212292304896',
#      u'source_user_id': 44135317,
#      u'source_user_id_str': u'44135317',
#      u'type': u'photo',
#      u'url': u'https://t.co/4zhlQGjWMh'}]},
#   u'favorite_count': 0,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 791747759690883072,
#   u'id_str': u'791747759690883072',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'is_quote_status': False,
#   u'lang': u'en',
#   u'metadata': {u'iso_language_code': u'en', u'result_type': u'recent'},
#   u'place': None,
#   u'possibly_sensitive': False,
#   u'retweet_count': 6,
#   u'retweeted': False,
#   u'retweeted_status': {u'contributors': None,
#    u'coordinates': None,
#    u'created_at': u'Thu Oct 27 03:54:29 +0000 2016',
#    u'entities': {u'hashtags': [],
#     u'media': [{u'display_url': u'pic.twitter.com/4zhlQGjWMh',
#       u'expanded_url': u'https://twitter.com/VarsityAces/status/791488212292304896/photo/1',
#       u'id': 791488202620239874,
#       u'id_str': u'791488202620239874',
#       u'indices': [68, 91],
#       u'media_url': u'http://pbs.twimg.com/media/CvvuU6kXgAIWBVu.jpg',
#       u'media_url_https': u'https://pbs.twimg.com/media/CvvuU6kXgAIWBVu.jpg',
#       u'sizes': {u'large': {u'h': 773, u'resize': u'fit', u'w': 1000},
#        u'medium': {u'h': 773, u'resize': u'fit', u'w': 1000},
#        u'small': {u'h': 526, u'resize': u'fit', u'w': 680},
#        u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}},
#       u'type': u'photo',
#       u'url': u'https://t.co/4zhlQGjWMh'}],
#     u'symbols': [],
#     u'urls': [{u'display_url': u'bit.ly/2ed82S7',
#       u'expanded_url': u'http://bit.ly/2ed82S7',
#       u'indices': [44, 67],
#       u'url': u'https://t.co/Q8vANHPYAe'}],
#     u'user_mentions': []},
#    u'extended_entities': {u'media': [{u'display_url': u'pic.twitter.com/4zhlQGjWMh',
#       u'expanded_url': u'https://twitter.com/VarsityAces/status/791488212292304896/photo/1',
#       u'id': 791488202620239874,
#       u'id_str': u'791488202620239874',
#       u'indices': [68, 91],
#       u'media_url': u'http://pbs.twimg.com/media/CvvuU6kXgAIWBVu.jpg',
#       u'media_url_https': u'https://pbs.twimg.com/media/CvvuU6kXgAIWBVu.jpg',
#       u'sizes': {u'large': {u'h': 773, u'resize': u'fit', u'w': 1000},
#        u'medium': {u'h': 773, u'resize': u'fit', u'w': 1000},
#        u'small': {u'h': 526, u'resize': u'fit', u'w': 680},
#        u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}},
#       u'type': u'photo',
#       u'url': u'https://t.co/4zhlQGjWMh'}]},
#    u'favorite_count': 6,
#    u'favorited': False,
#    u'geo': None,
#    u'id': 791488212292304896,
#    u'id_str': u'791488212292304896',
#    u'in_reply_to_screen_name': None,
#    u'in_reply_to_status_id': None,
#    u'in_reply_to_status_id_str': None,
#    u'in_reply_to_user_id': None,
#    u'in_reply_to_user_id_str': None,
#    u'is_quote_status': False,
#    u'lang': u'en',
#    u'metadata': {u'iso_language_code': u'en', u'result_type': u'recent'},
#    u'place': None,
#    u'possibly_sensitive': False,
#    u'retweet_count': 6,
#    u'retweeted': False,
#    u'source': u'<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    u'text': u'H.S. football: Pompton Lakes won\u2019t stop now https://t.co/Q8vANHPYAe https://t.co/4zhlQGjWMh',
#    u'truncated': False,
#    u'user': {u'contributors_enabled': False,
#     u'created_at': u'Tue Jun 02 15:11:19 +0000 2009',
#     u'default_profile': False,
#     u'default_profile_image': False,
#     u'description': u'The people, stories and scores of North Jersey high school sports, brought to you by The Record local sports staff. -- E-mail: VarsityAces@northjersey.com',
#     u'entities': {u'description': {u'urls': []},
#      u'url': {u'urls': [{u'display_url': u'northjersey.com/varsityaces',
#         u'expanded_url': u'http://www.northjersey.com/varsityaces',
#         u'indices': [0, 22],
#         u'url': u'http://t.co/a1jiHxyujq'}]}},
#     u'favourites_count': 1238,
#     u'follow_request_sent': None,
#     u'followers_count': 134155,
#     u'following': None,
#     u'friends_count': 4115,
#     u'geo_enabled': True,
#     u'has_extended_profile': False,
#     u'id': 44135317,
#     u'id_str': u'44135317',
#     u'is_translation_enabled': False,
#     u'is_translator': False,
#     u'lang': u'en',
#     u'listed_count': 94,
#     u'location': u'North Jersey',
#     u'name': u'Varsity Aces',
#     u'notifications': None,
#     u'profile_background_color': u'131516',
#     u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme14/bg.gif',
#     u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme14/bg.gif',
#     u'profile_background_tile': True,
#     u'profile_image_url': u'http://pbs.twimg.com/profile_images/497873047450165248/2j2UT9Jn_normal.png',
#     u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/497873047450165248/2j2UT9Jn_normal.png',
#     u'profile_link_color': u'8A0527',
#     u'profile_sidebar_border_color': u'FFFFFF',
#     u'profile_sidebar_fill_color': u'EFEFEF',
#     u'profile_text_color': u'333333',
#     u'profile_use_background_image': True,
#     u'protected': False,
#     u'screen_name': u'VarsityAces',
#     u'statuses_count': 88140,
#     u'time_zone': u'Eastern Time (US & Canada)',
#     u'translator_type': u'none',
#     u'url': u'http://t.co/a1jiHxyujq',
#     u'utc_offset': -14400,
#     u'verified': True}},
#   u'source': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   u'text': u'RT @VarsityAces: H.S. football: Pompton Lakes won\u2019t stop now https://t.co/Q8vANHPYAe https://t.co/4zhlQGjWMh',
#   u'truncated': False,
#   u'user': {u'contributors_enabled': False,
#    u'created_at': u'Mon Dec 26 18:41:03 +0000 2011',
#    u'default_profile': False,
#    u'default_profile_image': False,
#    u'description': u'\u272fNew Jersey //MIGO\u3072 insta:_mig00_',
#    u'entities': {u'description': {u'urls': []}},
#    u'favourites_count': 6827,
#    u'follow_request_sent': None,
#    u'followers_count': 292,
#    u'following': None,
#    u'friends_count': 560,
#    u'geo_enabled': True,
#    u'has_extended_profile': False,
#    u'id': 447298090,
#    u'id_str': u'447298090',
#    u'is_translation_enabled': False,
#    u'is_translator': False,
#    u'lang': u'en',
#    u'listed_count': 0,
#    u'location': u'',
#    u'name': u'MIGO_0',
#    u'notifications': None,
#    u'profile_background_color': u'131516',
#    u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme14/bg.gif',
#    u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme14/bg.gif',
#    u'profile_background_tile': True,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/447298090/1476284375',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/787873333807316993/rU7QnJ8j_normal.jpg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/787873333807316993/rU7QnJ8j_normal.jpg',
#    u'profile_link_color': u'009999',
#    u'profile_sidebar_border_color': u'EEEEEE',
#    u'profile_sidebar_fill_color': u'EFEFEF',
#    u'profile_text_color': u'333333',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'spikeygarcia',
#    u'statuses_count': 1492,
#    u'time_zone': u'Central Time (US & Canada)',
#    u'translator_type': u'none',
#    u'url': None,
#    u'utc_offset': -18000,
#    u'verified': False}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Thu Oct 27 21:05:50 +0000 2016',
#   u'entities': {u'hashtags': [{u'indices': [37, 46], u'text': u'Warriors'}],
#    u'media': [{u'display_url': u'pic.twitter.com/1SNwK4L1qc',
#      u'expanded_url': u'https://twitter.com/nbcbayarea/status/791747758894018560/photo/1',
#      u'id': 791747756423512065,
#      u'id_str': u'791747756423512065',
#      u'indices': [88, 111],
#      u'media_url': u'http://pbs.twimg.com/media/CvzaY71WAAE8r6D.jpg',
#      u'media_url_https': u'https://pbs.twimg.com/media/CvzaY71WAAE8r6D.jpg',
#      u'sizes': {u'large': {u'h': 387, u'resize': u'fit', u'w': 721},
#       u'medium': {u'h': 387, u'resize': u'fit', u'w': 721},
#       u'small': {u'h': 365, u'resize': u'fit', u'w': 680},
#       u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}},
#      u'type': u'photo',
#      u'url': u'https://t.co/1SNwK4L1qc'}],
#    u'symbols': [],
#    u'urls': [{u'display_url': u'nbcbay.com/6GnSDwd',
#      u'expanded_url': u'http://nbcbay.com/6GnSDwd',
#      u'indices': [64, 87],
#      u'url': u'https://t.co/5w4fwUOKzv'}],
#    u'user_mentions': []},
#   u'extended_entities': {u'media': [{u'display_url': u'pic.twitter.com/1SNwK4L1qc',
#      u'expanded_url': u'https://twitter.com/nbcbayarea/status/791747758894018560/photo/1',
#      u'id': 791747756423512065,
#      u'id_str': u'791747756423512065',
#      u'indices': [88, 111],
#      u'media_url': u'http://pbs.twimg.com/media/CvzaY71WAAE8r6D.jpg',
#      u'media_url_https': u'https://pbs.twimg.com/media/CvzaY71WAAE8r6D.jpg',
#      u'sizes': {u'large': {u'h': 387, u'resize': u'fit', u'w': 721},
#       u'medium': {u'h': 387, u'resize': u'fit', u'w': 721},
#       u'small': {u'h': 365, u'resize': u'fit', u'w': 680},
#       u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}},
#      u'type': u'photo',
#      u'url': u'https://t.co/1SNwK4L1qc'}]},
#   u'favorite_count': 0,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 791747758894018560,
#   u'id_str': u'791747758894018560',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'is_quote_status': False,
#   u'lang': u'en',
#   u'metadata': {u'iso_language_code': u'en', u'result_type': u'recent'},
#   u'place': None,
#   u'possibly_sensitive': False,
#   u'retweet_count': 0,
#   u'retweeted': False,
#   u'source': u'<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>',
#   u'text': u'Beyonce sports sparkly sock boots at #Warriors game in Oakland. https://t.co/5w4fwUOKzv https://t.co/1SNwK4L1qc',
#   u'truncated': False,
#   u'user': {u'contributors_enabled': False,
#    u'created_at': u'Wed Feb 04 21:41:26 +0000 2009',
#    u'default_profile': False,
#    u'default_profile_image': False,
#    u'description': u'Thank you for stopping by @NBCBayArea - the place to go for exclusive local stories, the latest breaking news, weather updates and more.',
#    u'entities': {u'description': {u'urls': []},
#     u'url': {u'urls': [{u'display_url': u'nbcbayarea.com',
#        u'expanded_url': u'http://nbcbayarea.com',
#        u'indices': [0, 23],
#        u'url': u'https://t.co/GItaIcePJK'}]}},
#    u'favourites_count': 2660,
#    u'follow_request_sent': None,
#    u'followers_count': 193913,
#    u'following': None,
#    u'friends_count': 2461,
#    u'geo_enabled': True,
#    u'has_extended_profile': False,
#    u'id': 20097362,
#    u'id_str': u'20097362',
#    u'is_translation_enabled': False,
#    u'is_translator': False,
#    u'lang': u'en',
#    u'listed_count': 2828,
#    u'location': u'San Francisco Bay Area',
#    u'name': u'NBC Bay Area',
#    u'notifications': None,
#    u'profile_background_color': u'0082C8',
#    u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/723861891/b314019172979d99ed50f5d45be491b5.jpeg',
#    u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/723861891/b314019172979d99ed50f5d45be491b5.jpeg',
#    u'profile_background_tile': False,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/20097362/1476658286',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/767812410828697601/0AkRxlsB_normal.jpg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/767812410828697601/0AkRxlsB_normal.jpg',
#    u'profile_link_color': u'0099B9',
#    u'profile_sidebar_border_color': u'FFFFFF',
#    u'profile_sidebar_fill_color': u'95E8EC',
#    u'profile_text_color': u'3C3940',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'nbcbayarea',
#    u'statuses_count': 184089,
#    u'time_zone': u'Pacific Time (US & Canada)',
#    u'translator_type': u'none',
#    u'url': u'https://t.co/GItaIcePJK',
#    u'utc_offset': -25200,
#    u'verified': True}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Thu Oct 27 21:05:50 +0000 2016',
#   u'entities': {u'hashtags': [{u'indices': [90, 98], u'text': u'science'}],
#    u'symbols': [],
#    u'urls': [{u'display_url': u'goo.gl/fb/PmYYtJ',
#      u'expanded_url': u'https://goo.gl/fb/PmYYtJ',
#      u'indices': [66, 89],
#      u'url': u'https://t.co/kv3qxY6Nmg'}],
#    u'user_mentions': []},
#   u'favorite_count': 0,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 791747758420025344,
#   u'id_str': u'791747758420025344',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'is_quote_status': False,
#   u'lang': u'en',
#   u'metadata': {u'iso_language_code': u'en', u'result_type': u'recent'},
#   u'place': None,
#   u'possibly_sensitive': False,
#   u'retweet_count': 0,
#   u'retweeted': False,
#   u'source': u'<a href="http://www.google.com/" rel="nofollow">Google</a>',
#   u'text': u'The Talent Code: Unlocking the Secret of Skill in Sports, Art,... https://t.co/kv3qxY6Nmg #science',
#   u'truncated': False,
#   u'user': {u'contributors_enabled': False,
#    u'created_at': u'Sun Sep 14 19:58:52 +0000 2014',
#    u'default_profile': True,
#    u'default_profile_image': False,
#    u'description': u'If you need space, work at NASA.',
#    u'entities': {u'description': {u'urls': []}},
#    u'favourites_count': 16603,
#    u'follow_request_sent': None,
#    u'followers_count': 29326,
#    u'following': None,
#    u'friends_count': 27334,
#    u'geo_enabled': False,
#    u'has_extended_profile': False,
#    u'id': 2810050196,
#    u'id_str': u'2810050196',
#    u'is_translation_enabled': True,
#    u'is_translator': False,
#    u'lang': u'en',
#    u'listed_count': 1643,
#    u'location': u'Utah',
#    u'name': u'Amanda',
#    u'notifications': None,
#    u'profile_background_color': u'C0DEED',
#    u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme1/bg.png',
#    u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme1/bg.png',
#    u'profile_background_tile': False,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/2810050196/1410724785',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/511242894947016704/fHdtFu1n_normal.jpeg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/511242894947016704/fHdtFu1n_normal.jpeg',
#    u'profile_link_color': u'0084B4',
#    u'profile_sidebar_border_color': u'C0DEED',
#    u'profile_sidebar_fill_color': u'DDEEF6',
#    u'profile_text_color': u'333333',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'amandsst',
#    u'statuses_count': 905939,
#    u'time_zone': u'Mountain Time (US & Canada)',
#    u'translator_type': u'none',
#    u'url': None,
#    u'utc_offset': -21600,
#    u'verified': False}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Thu Oct 27 21:05:50 +0000 2016',
#   u'entities': {u'hashtags': [],
#    u'symbols': [],
#    u'urls': [],
#    u'user_mentions': [{u'id': 46758606,
#      u'id_str': u'46758606',
#      u'indices': [3, 14],
#      u'name': u'Ben Shpigel',
#      u'screen_name': u'benshpigel'}]},
#   u'favorite_count': 0,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 791747758210199552,
#   u'id_str': u'791747758210199552',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'is_quote_status': False,
#   u'lang': u'en',
#   u'metadata': {u'iso_language_code': u'en', u'result_type': u'recent'},
#   u'place': None,
#   u'retweet_count': 15,
#   u'retweeted': False,
#   u'retweeted_status': {u'contributors': None,
#    u'coordinates': None,
#    u'created_at': u'Thu Oct 27 19:01:36 +0000 2016',
#    u'entities': {u'hashtags': [],
#     u'symbols': [],
#     u'urls': [{u'display_url': u'nyti.ms/2eKRdBy',
#       u'expanded_url': u'http://nyti.ms/2eKRdBy',
#       u'indices': [117, 140],
#       u'url': u'https://t.co/NytZ50hnpF'}],
#     u'user_mentions': []},
#    u'favorite_count': 20,
#    u'favorited': False,
#    u'geo': None,
#    u'id': 791716496221306884,
#    u'id_str': u'791716496221306884',
#    u'in_reply_to_screen_name': None,
#    u'in_reply_to_status_id': None,
#    u'in_reply_to_status_id_str': None,
#    u'in_reply_to_user_id': None,
#    u'in_reply_to_user_id_str': None,
#    u'is_quote_status': False,
#    u'lang': u'en',
#    u'metadata': {u'iso_language_code': u'en', u'result_type': u'recent'},
#    u'place': None,
#    u'possibly_sensitive': False,
#    u'retweet_count': 15,
#    u'retweeted': False,
#    u'source': u'<a href="https://bitly.com/" rel="nofollow">Bitly</a>',
#    u'text': u'The Oilers, after 10 years in the wilderness, are pining for playoff hockey + they might get it, too. From Edmonton: https://t.co/NytZ50hnpF',
#    u'truncated': False,
#    u'user': {u'contributors_enabled': False,
#     u'created_at': u'Fri Jun 12 21:55:45 +0000 2009',
#     u'default_profile': False,
#     u'default_profile_image': False,
#     u'description': u'Jets/NFL/etc @NYTSports. Husband of one, dad of two. Alum: @councilrocksd, @emorywheel, @columbiajourn, @dallasnews. 1988 Bucks County Mall Spelling Bee champ.',
#     u'entities': {u'description': {u'urls': []},
#      u'url': {u'urls': [{u'display_url': u'topics.nytimes.com/topics/referen\u2026',
#         u'expanded_url': u'http://topics.nytimes.com/topics/reference/timestopics/people/s/ben_shpigel/index.html',
#         u'indices': [0, 23],
#         u'url': u'https://t.co/oxms22bsRt'}]}},
#     u'favourites_count': 1006,
#     u'follow_request_sent': None,
#     u'followers_count': 9739,
#     u'following': None,
#     u'friends_count': 1210,
#     u'geo_enabled': True,
#     u'has_extended_profile': True,
#     u'id': 46758606,
#     u'id_str': u'46758606',
#     u'is_translation_enabled': False,
#     u'is_translator': False,
#     u'lang': u'en',
#     u'listed_count': 888,
#     u'location': u'EVERYWHERE \u2014',
#     u'name': u'Ben Shpigel',
#     u'notifications': None,
#     u'profile_background_color': u'000000',
#     u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme1/bg.png',
#     u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme1/bg.png',
#     u'profile_background_tile': False,
#     u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/46758606/1452612439',
#     u'profile_image_url': u'http://pbs.twimg.com/profile_images/772434252961021952/LBJItNLw_normal.jpg',
#     u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/772434252961021952/LBJItNLw_normal.jpg',
#     u'profile_link_color': u'B30009',
#     u'profile_sidebar_border_color': u'000000',
#     u'profile_sidebar_fill_color': u'000000',
#     u'profile_text_color': u'000000',
#     u'profile_use_background_image': False,
#     u'protected': False,
#     u'screen_name': u'benshpigel',
#     u'statuses_count': 15471,
#     u'time_zone': u'Eastern Time (US & Canada)',
#     u'translator_type': u'none',
#     u'url': u'https://t.co/oxms22bsRt',
#     u'utc_offset': -14400,
#     u'verified': True}},
#   u'source': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   u'text': u'RT @benshpigel: The Oilers, after 10 years in the wilderness, are pining for playoff hockey + they might get it, too. From Edmonton: https:\u2026',
#   u'truncated': False,
#   u'user': {u'contributors_enabled': False,
#    u'created_at': u'Thu Aug 29 23:53:40 +0000 2013',
#    u'default_profile': True,
#    u'default_profile_image': False,
#    u'description': u'Blue and Orange.',
#    u'entities': {u'description': {u'urls': []}},
#    u'favourites_count': 684,
#    u'follow_request_sent': None,
#    u'followers_count': 179,
#    u'following': None,
#    u'friends_count': 219,
#    u'geo_enabled': False,
#    u'has_extended_profile': False,
#    u'id': 1711300574,
#    u'id_str': u'1711300574',
#    u'is_translation_enabled': False,
#    u'is_translator': False,
#    u'lang': u'en',
#    u'listed_count': 2,
#    u'location': u'Edmonton, Alberta',
#    u'name': u'ROSS',
#    u'notifications': None,
#    u'profile_background_color': u'C0DEED',
#    u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme1/bg.png',
#    u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme1/bg.png',
#    u'profile_background_tile': False,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/1711300574/1461803080',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/789368738516729858/hU92fuQD_normal.jpg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/789368738516729858/hU92fuQD_normal.jpg',
#    u'profile_link_color': u'0084B4',
#    u'profile_sidebar_border_color': u'C0DEED',
#    u'profile_sidebar_fill_color': u'DDEEF6',
#    u'profile_text_color': u'333333',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'McOilers93',
#    u'statuses_count': 2787,
#    u'time_zone': u'Pacific Time (US & Canada)',
#    u'translator_type': u'none',
#    u'url': None,
#    u'utc_offset': -25200,
#    u'verified': False}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Thu Oct 27 21:05:50 +0000 2016',
#   u'entities': {u'hashtags': [],
#    u'symbols': [],
#    u'urls': [{u'display_url': u'vine.co/v/MrTlImjlai1',
#      u'expanded_url': u'https://vine.co/v/MrTlImjlai1',
#      u'indices': [55, 78],
#      u'url': u'https://t.co/VCSA5epUpK'}],
#    u'user_mentions': [{u'id': 498177610,
#      u'id_str': u'498177610',
#      u'indices': [3, 16],
#      u'name': u'Best Vines',
#      u'screen_name': u'TheFunnyVine'}]},
#   u'favorite_count': 0,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 791747757912588288,
#   u'id_str': u'791747757912588288',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'is_quote_status': False,
#   u'lang': u'en',
#   u'metadata': {u'iso_language_code': u'en', u'result_type': u'recent'},
#   u'place': None,
#   u'possibly_sensitive': False,
#   u'retweet_count': 893,
#   u'retweeted': False,
#   u'retweeted_status': {u'contributors': None,
#    u'coordinates': None,
#    u'created_at': u'Thu Oct 27 19:15:23 +0000 2016',
#    u'entities': {u'hashtags': [],
#     u'symbols': [],
#     u'urls': [{u'display_url': u'vine.co/v/MrTlImjlai1',
#       u'expanded_url': u'https://vine.co/v/MrTlImjlai1',
#       u'indices': [37, 60],
#       u'url': u'https://t.co/VCSA5epUpK'}],
#     u'user_mentions': []},
#    u'favorite_count': 1371,
#    u'favorited': False,
#    u'geo': None,
#    u'id': 791719962922610689,
#    u'id_str': u'791719962922610689',
#    u'in_reply_to_screen_name': None,
#    u'in_reply_to_status_id': None,
#    u'in_reply_to_status_id_str': None,
#    u'in_reply_to_user_id': None,
#    u'in_reply_to_user_id_str': None,
#    u'is_quote_status': False,
#    u'lang': u'en',
#    u'metadata': {u'iso_language_code': u'en', u'result_type': u'recent'},
#    u'place': None,
#    u'possibly_sensitive': False,
#    u'retweet_count': 893,
#    u'retweeted': False,
#    u'source': u'<a href="http://www.tweetcaster.com" rel="nofollow">TweetCaster for Android</a>',
#    u'text': u'the greatest sports vine of all time https://t.co/VCSA5epUpK',
#    u'truncated': False,
#    u'user': {u'contributors_enabled': False,
#     u'created_at': u'Mon Feb 20 19:31:53 +0000 2012',
#     u'default_profile': False,
#     u'default_profile_image': False,
#     u'description': u'We post all the best Vines. Not Affiliated With Vine! Facebook: @thefunnyvine Instagram: @the.Funny.vine Contact: thefunnyvine@gmail.com',
#     u'entities': {u'description': {u'urls': []}},
#     u'favourites_count': 8,
#     u'follow_request_sent': None,
#     u'followers_count': 1373391,
#     u'following': None,
#     u'friends_count': 10,
#     u'geo_enabled': False,
#     u'has_extended_profile': False,
#     u'id': 498177610,
#     u'id_str': u'498177610',
#     u'is_translation_enabled': False,
#     u'is_translator': False,
#     u'lang': u'en',
#     u'listed_count': 1588,
#     u'location': u'',
#     u'name': u'Best Vines',
#     u'notifications': None,
#     u'profile_background_color': u'1A1B1F',
#     u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/863599808/8409a6c3f97da1e08d2c670b2e83331f.jpeg',
#     u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/863599808/8409a6c3f97da1e08d2c670b2e83331f.jpeg',
#     u'profile_background_tile': True,
#     u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/498177610/1431213460',
#     u'profile_image_url': u'http://pbs.twimg.com/profile_images/597184401873772544/lc28AVX7_normal.png',
#     u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/597184401873772544/lc28AVX7_normal.png',
#     u'profile_link_color': u'2FC2EF',
#     u'profile_sidebar_border_color': u'FFFFFF',
#     u'profile_sidebar_fill_color': u'252429',
#     u'profile_text_color': u'666666',
#     u'profile_use_background_image': True,
#     u'protected': False,
#     u'screen_name': u'TheFunnyVine',
#     u'statuses_count': 12122,
#     u'time_zone': u'Eastern Time (US & Canada)',
#     u'translator_type': u'none',
#     u'url': None,
#     u'utc_offset': -14400,
#     u'verified': False}},
#   u'source': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   u'text': u'RT @TheFunnyVine: the greatest sports vine of all time https://t.co/VCSA5epUpK',
#   u'truncated': False,
#   u'user': {u'contributors_enabled': False,
#    u'created_at': u'Wed Mar 18 23:33:51 +0000 2015',
#    u'default_profile': True,
#    u'default_profile_image': False,
#    u'description': u'Shoot to kill... coming to a penitentiary near you...',
#    u'entities': {u'description': {u'urls': []}},
#    u'favourites_count': 519,
#    u'follow_request_sent': None,
#    u'followers_count': 44,
#    u'following': None,
#    u'friends_count': 42,
#    u'geo_enabled': True,
#    u'has_extended_profile': False,
#    u'id': 3095646227,
#    u'id_str': u'3095646227',
#    u'is_translation_enabled': False,
#    u'is_translator': False,
#    u'lang': u'en-AU',
#    u'listed_count': 0,
#    u'location': u'',
#    u'name': u'Guerilla Unit',
#    u'notifications': None,
#    u'profile_background_color': u'C0DEED',
#    u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme1/bg.png',
#    u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme1/bg.png',
#    u'profile_background_tile': False,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/3095646227/1471441284',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/734922953528315905/-KuEwlEe_normal.jpg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/734922953528315905/-KuEwlEe_normal.jpg',
#    u'profile_link_color': u'0084B4',
#    u'profile_sidebar_border_color': u'C0DEED',
#    u'profile_sidebar_fill_color': u'DDEEF6',
#    u'profile_text_color': u'333333',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'TheRealJbreezy3',
#    u'statuses_count': 1273,
#    u'time_zone': None,
#    u'translator_type': u'none',
#    u'url': None,
#    u'utc_offset': None,
#    u'verified': False}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Thu Oct 27 21:05:48 +0000 2016',
#   u'entities': {u'hashtags': [],
#    u'symbols': [],
#    u'urls': [{u'display_url': u'trib.al/2Q9mVfu',
#      u'expanded_url': u'http://trib.al/2Q9mVfu',
#      u'indices': [38, 61],
#      u'url': u'https://t.co/N6xQ62DNIh'}],
#    u'user_mentions': []},
#   u'favorite_count': 0,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 791747753189765121,
#   u'id_str': u'791747753189765121',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'is_quote_status': False,
#   u'lang': u'en',
#   u'metadata': {u'iso_language_code': u'en', u'result_type': u'recent'},
#   u'place': None,
#   u'possibly_sensitive': False,
#   u'retweet_count': 0,
#   u'retweeted': False,
#   u'source': u'<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>',
#   u'text': u'Sports schedule for Thursday, Oct. 27 https://t.co/N6xQ62DNIh',
#   u'truncated': False,
#   u'user': {u'contributors_enabled': False,
#    u'created_at': u'Fri Sep 23 16:08:51 +0000 2011',
#    u'default_profile': False,
#    u'default_profile_image': False,
#    u'description': u'',
#    u'entities': {u'description': {u'urls': []},
#     u'url': {u'urls': [{u'display_url': u'theosakisreview.com',
#        u'expanded_url': u'http://www.theosakisreview.com/',
#        u'indices': [0, 22],
#        u'url': u'http://t.co/6B5D1wgonZ'}]}},
#    u'favourites_count': 9,
#    u'follow_request_sent': None,
#    u'followers_count': 470,
#    u'following': None,
#    u'friends_count': 350,
#    u'geo_enabled': True,
#    u'has_extended_profile': False,
#    u'id': 378669161,
#    u'id_str': u'378669161',
#    u'is_translation_enabled': False,
#    u'is_translator': False,
#    u'lang': u'en',
#    u'listed_count': 26,
#    u'location': u'Osakis, MN',
#    u'name': u'The Osakis Review',
#    u'notifications': None,
#    u'profile_background_color': u'FFFFFF',
#    u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/337984013/Osakis-Review-Twitter-Bg-Generic-copy.jpg',
#    u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/337984013/Osakis-Review-Twitter-Bg-Generic-copy.jpg',
#    u'profile_background_tile': True,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/378669161/1404311623',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/1564017111/osakis-review-profile-pic_normal.jpg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/1564017111/osakis-review-profile-pic_normal.jpg',
#    u'profile_link_color': u'1F98C7',
#    u'profile_sidebar_border_color': u'18191B',
#    u'profile_sidebar_fill_color': u'F0F0F0',
#    u'profile_text_color': u'000000',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'TheOsakisReview',
#    u'statuses_count': 1061,
#    u'time_zone': u'Central Time (US & Canada)',
#    u'translator_type': u'none',
#    u'url': u'http://t.co/6B5D1wgonZ',
#    u'utc_offset': -18000,
#    u'verified': False}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Thu Oct 27 21:05:48 +0000 2016',
#   u'entities': {u'hashtags': [],
#    u'symbols': [],
#    u'urls': [{u'display_url': u'bit.ly/2eLgYS4',
#      u'expanded_url': u'http://bit.ly/2eLgYS4',
#      u'indices': [68, 91],
#      u'url': u'https://t.co/cXTDitxCXH'}],
#    u'user_mentions': []},
#   u'favorite_count': 0,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 791747753072218112,
#   u'id_str': u'791747753072218112',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'is_quote_status': False,
#   u'lang': u'en',
#   u'metadata': {u'iso_language_code': u'en', u'result_type': u'recent'},
#   u'place': None,
#   u'possibly_sensitive': False,
#   u'retweet_count': 0,
#   u'retweeted': False,
#   u'source': u'<a href="http://dlvr.it" rel="nofollow">dlvr.it</a>',
#   u'text': u"Rodgers responds to story about 'grandpa' comment in new Favre book https://t.co/cXTDitxCXH",
#   u'truncated': False,
#   u'user': {u'contributors_enabled': False,
#    u'created_at': u'Mon Jun 20 22:28:40 +0000 2011',
#    u'default_profile': False,
#    u'default_profile_image': False,
#    u'description': u'Tweeting news, mostly about great authors and their creations.',
#    u'entities': {u'description': {u'urls': []},
#     u'url': {u'urls': [{u'display_url': u'bit.ly/EnchantedEd',
#        u'expanded_url': u'http://bit.ly/EnchantedEd',
#        u'indices': [0, 23],
#        u'url': u'https://t.co/otymxQykLr'}]}},
#    u'favourites_count': 56,
#    u'follow_request_sent': None,
#    u'followers_count': 310,
#    u'following': None,
#    u'friends_count': 449,
#    u'geo_enabled': False,
#    u'has_extended_profile': False,
#    u'id': 321028297,
#    u'id_str': u'321028297',
#    u'is_translation_enabled': False,
#    u'is_translator': False,
#    u'lang': u'en',
#    u'listed_count': 21,
#    u'location': u'Salem',
#    u'name': u'Jesse @AmblingAudio',
#    u'notifications': None,
#    u'profile_background_color': u'C0DEED',
#    u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/274296205/Twitter-Ambling.jpg',
#    u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/274296205/Twitter-Ambling.jpg',
#    u'profile_background_tile': False,
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/1405302045/Ambling_Books_-_icon_-_73x73_normal.png',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/1405302045/Ambling_Books_-_icon_-_73x73_normal.png',
#    u'profile_link_color': u'0084B4',
#    u'profile_sidebar_border_color': u'C0DEED',
#    u'profile_sidebar_fill_color': u'DDEEF6',
#    u'profile_text_color': u'333333',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'AmblingAudio',
#    u'statuses_count': 7500,
#    u'time_zone': u'Central Time (US & Canada)',
#    u'translator_type': u'none',
#    u'url': u'https://t.co/otymxQykLr',
#    u'utc_offset': -18000,
#    u'verified': False}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Thu Oct 27 21:05:48 +0000 2016',
#   u'entities': {u'hashtags': [{u'indices': [28, 37], u'text': u'Riquelme'}],
#    u'symbols': [],
#    u'urls': [],
#    u'user_mentions': [{u'id': 782805591282610176,
#      u'id_str': u'782805591282610176',
#      u'indices': [3, 19],
#      u'name': u'Boca mi Enfermedad',
#      u'screen_name': u'enfermedadxboca'}]},
#   u'favorite_count': 0,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 791747752883527680,
#   u'id_str': u'791747752883527680',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'is_quote_status': False,
#   u'lang': u'es',
#   u'metadata': {u'iso_language_code': u'es', u'result_type': u'recent'},
#   u'place': None,
#   u'retweet_count': 11,
#   u'retweeted': False,
#   u'retweeted_status': {u'contributors': None,
#    u'coordinates': None,
#    u'created_at': u'Thu Oct 27 20:25:27 +0000 2016',
#    u'entities': {u'hashtags': [{u'indices': [7, 16], u'text': u'Riquelme'}],
#     u'media': [{u'display_url': u'pic.twitter.com/FZsXn9CcbA',
#       u'expanded_url': u'https://twitter.com/enfermedadxboca/status/791737597768896516/photo/1',
#       u'id': 791737583688617985,
#       u'id_str': u'791737583688617985',
#       u'indices': [116, 139],
#       u'media_url': u'http://pbs.twimg.com/media/CvzRIzcWEAEi4SL.jpg',
#       u'media_url_https': u'https://pbs.twimg.com/media/CvzRIzcWEAEi4SL.jpg',
#       u'sizes': {u'large': {u'h': 338, u'resize': u'fit', u'w': 600},
#        u'medium': {u'h': 338, u'resize': u'fit', u'w': 600},
#        u'small': {u'h': 338, u'resize': u'fit', u'w': 600},
#        u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}},
#       u'type': u'photo',
#       u'url': u'https://t.co/FZsXn9CcbA'}],
#     u'symbols': [],
#     u'urls': [],
#     u'user_mentions': []},
#    u'extended_entities': {u'media': [{u'display_url': u'pic.twitter.com/FZsXn9CcbA',
#       u'expanded_url': u'https://twitter.com/enfermedadxboca/status/791737597768896516/photo/1',
#       u'id': 791737583688617985,
#       u'id_str': u'791737583688617985',
#       u'indices': [116, 139],
#       u'media_url': u'http://pbs.twimg.com/media/CvzRIzcWEAEi4SL.jpg',
#       u'media_url_https': u'https://pbs.twimg.com/media/CvzRIzcWEAEi4SL.jpg',
#       u'sizes': {u'large': {u'h': 338, u'resize': u'fit', u'w': 600},
#        u'medium': {u'h': 338, u'resize': u'fit', u'w': 600},
#        u'small': {u'h': 338, u'resize': u'fit', u'w': 600},
#        u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}},
#       u'type': u'photo',
#       u'url': u'https://t.co/FZsXn9CcbA'}]},
#    u'favorite_count': 4,
#    u'favorited': False,
#    u'geo': None,
#    u'id': 791737597768896516,
#    u'id_str': u'791737597768896516',
#    u'in_reply_to_screen_name': None,
#    u'in_reply_to_status_id': None,
#    u'in_reply_to_status_id_str': None,
#    u'in_reply_to_user_id': None,
#    u'in_reply_to_user_id_str': None,
#    u'is_quote_status': False,
#    u'lang': u'es',
#    u'metadata': {u'iso_language_code': u'es', u'result_type': u'recent'},
#    u'place': None,
#    u'possibly_sensitive': False,
#    u'retweet_count': 11,
#    u'retweeted': False,
#    u'source': u'<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    u'text': u'Boca | #Riquelme en TyC Sports: "Ac\xe1 soy feliz. Tengo que hablar con el Presidente y ver cuando hago mi despedida". https://t.co/FZsXn9CcbA',
#    u'truncated': False,
#    u'user': {u'contributors_enabled': False,
#     u'created_at': u'Mon Oct 03 04:52:51 +0000 2016',
#     u'default_profile': True,
#     u'default_profile_image': False,
#     u'description': u'La informaci\xf3n del m\xe1s grande est\xe1 ac\xe1, en Boca mi Enfermedad',
#     u'entities': {u'description': {u'urls': []}},
#     u'favourites_count': 7,
#     u'follow_request_sent': None,
#     u'followers_count': 886,
#     u'following': None,
#     u'friends_count': 3964,
#     u'geo_enabled': False,
#     u'has_extended_profile': False,
#     u'id': 782805591282610176,
#     u'id_str': u'782805591282610176',
#     u'is_translation_enabled': False,
#     u'is_translator': False,
#     u'lang': u'es',
#     u'listed_count': 1,
#     u'location': u'La Boca, Argentina ',
#     u'name': u'Boca mi Enfermedad',
#     u'notifications': None,
#     u'profile_background_color': u'F5F8FA',
#     u'profile_background_image_url': None,
#     u'profile_background_image_url_https': None,
#     u'profile_background_tile': False,
#     u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/782805591282610176/1475470518',
#     u'profile_image_url': u'http://pbs.twimg.com/profile_images/782817121680121856/PCCUTYSO_normal.jpg',
#     u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/782817121680121856/PCCUTYSO_normal.jpg',
#     u'profile_link_color': u'2B7BB9',
#     u'profile_sidebar_border_color': u'C0DEED',
#     u'profile_sidebar_fill_color': u'DDEEF6',
#     u'profile_text_color': u'333333',
#     u'profile_use_background_image': True,
#     u'protected': False,
#     u'screen_name': u'enfermedadxboca',
#     u'statuses_count': 150,
#     u'time_zone': None,
#     u'translator_type': u'none',
#     u'url': None,
#     u'utc_offset': None,
#     u'verified': False}},
#   u'source': u'<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   u'text': u'RT @enfermedadxboca: Boca | #Riquelme en TyC Sports: "Ac\xe1 soy feliz. Tengo que hablar con el Presidente y ver cuando hago mi despedida". ht\u2026',
#   u'truncated': False,
#   u'user': {u'contributors_enabled': False,
#    u'created_at': u'Thu May 07 02:55:28 +0000 2015',
#    u'default_profile': False,
#    u'default_profile_image': False,
#    u'description': u'\u20222016\n\u2022Bostero\n\u2022\u26bd\U0001f499\U0001f49b\U0001f499\n\u2022Snap: altamiranofacu7',
#    u'entities': {u'description': {u'urls': []}},
#    u'favourites_count': 1209,
#    u'follow_request_sent': None,
#    u'followers_count': 434,
#    u'following': None,
#    u'friends_count': 408,
#    u'geo_enabled': True,
#    u'has_extended_profile': True,
#    u'id': 3239926768,
#    u'id_str': u'3239926768',
#    u'is_translation_enabled': False,
#    u'is_translator': False,
#    u'lang': u'es',
#    u'listed_count': 2,
#    u'location': u'Puerto Madryn, Argentina',
#    u'name': u'Facu',
#    u'notifications': None,
#    u'profile_background_color': u'FFCC4D',
#    u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/642187014088093696/Upl9fjBh.jpg',
#    u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/642187014088093696/Upl9fjBh.jpg',
#    u'profile_background_tile': True,
# ...
#    u'is_translator': False,
#    u'lang': u'ru',
#    u'listed_count': 253,
#    u'location': u'',
#    u'name': u'Andrea Gonzales',
#    u'notifications': None,
#    u'profile_background_color': u'F5F8FA',
#    u'profile_background_image_url': None,
#    u'profile_background_image_url_https': None,
#    u'profile_background_tile': False,
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/752789059551068160/gJy96r-Z_normal.jpg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/752789059551068160/gJy96r-Z_normal.jpg',
#    u'profile_link_color': u'2B7BB9',
#    u'profile_sidebar_border_color': u'C0DEED',
#    u'profile_sidebar_fill_color': u'DDEEF6',
#    u'profile_text_color': u'333333',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'molchanovonisi2',
#    u'statuses_count': 135151,
#    u'time_zone': None,
#    u'translator_type': u'none',
#    u'url': None,
#    u'utc_offset': None,
#    u'verified': False}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Thu Oct 27 21:05:46 +0000 2016',
#   u'entities': {u'hashtags': [],
#    u'media': [{u'display_url': u'pic.twitter.com/ETvAkWpX7a',
#      u'expanded_url': u'https://twitter.com/pzi_sports/status/791747742657753089/photo/1',
#      u'id': 791747741202251776,
#      u'id_str': u'791747741202251776',
#      u'indices': [93, 116],
#      u'media_url': u'http://pbs.twimg.com/media/CvzaYDIUAAAYd7V.jpg',
#      u'media_url_https': u'https://pbs.twimg.com/media/CvzaYDIUAAAYd7V.jpg',
#      u'sizes': {u'large': {u'h': 376, u'resize': u'fit', u'w': 670},
#       u'medium': {u'h': 376, u'resize': u'fit', u'w': 670},
#       u'small': {u'h': 376, u'resize': u'fit', u'w': 670},
#       u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}},
#      u'type': u'photo',
#      u'url': u'https://t.co/ETvAkWpX7a'}],
#    u'symbols': [],
#    u'urls': [{u'display_url': u'tinyurl.com/hpoaoda',
#      u'expanded_url': u'http://tinyurl.com/hpoaoda',
#      u'indices': [69, 92],
#      u'url': u'https://t.co/Wrnn9rWLjh'}],
#    u'user_mentions': []},
#   u'extended_entities': {u'media': [{u'display_url': u'pic.twitter.com/ETvAkWpX7a',
#      u'expanded_url': u'https://twitter.com/pzi_sports/status/791747742657753089/photo/1',
#      u'id': 791747741202251776,
#      u'id_str': u'791747741202251776',
#      u'indices': [93, 116],
#      u'media_url': u'http://pbs.twimg.com/media/CvzaYDIUAAAYd7V.jpg',
#      u'media_url_https': u'https://pbs.twimg.com/media/CvzaYDIUAAAYd7V.jpg',
#      u'sizes': {u'large': {u'h': 376, u'resize': u'fit', u'w': 670},
#       u'medium': {u'h': 376, u'resize': u'fit', u'w': 670},
#       u'small': {u'h': 376, u'resize': u'fit', u'w': 670},
#       u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}},
#      u'type': u'photo',
#      u'url': u'https://t.co/ETvAkWpX7a'}]},
#   u'favorite_count': 0,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 791747742657753089,
#   u'id_str': u'791747742657753089',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'is_quote_status': False,
#   u'lang': u'en',
#   u'metadata': {u'iso_language_code': u'en', u'result_type': u'recent'},
#   u'place': None,
#   u'possibly_sensitive': False,
#   u'retweet_count': 0,
#   u'retweeted': False,
#   u'source': u'<a href="http://pzisports.com" rel="nofollow">PZI Sports Post</a>',
#   u'text': u'FA Set Up investigation Into Crowd Trouble At West Ham v Chelsea Tie-https://t.co/Wrnn9rWLjh https://t.co/ETvAkWpX7a',
#   u'truncated': False,
#   u'user': {u'contributors_enabled': False,
#    u'created_at': u'Fri Nov 13 11:39:18 +0000 2015',
#    u'default_profile': True,
#    u'default_profile_image': False,
#    u'description': u"We bring Sports news all over the globe at it's peak...",
#    u'entities': {u'description': {u'urls': []}},
#    u'favourites_count': 30,
#    u'follow_request_sent': None,
#    u'followers_count': 268,
#    u'following': None,
#    u'friends_count': 1069,
#    u'geo_enabled': True,
#    u'has_extended_profile': False,
#    u'id': 4178456249,
#    u'id_str': u'4178456249',
#    u'is_translation_enabled': False,
#    u'is_translator': False,
#    u'lang': u'en',
#    u'listed_count': 5,
#    u'location': u'',
#    u'name': u'PZISPORTS',
#    u'notifications': None,
#    u'profile_background_color': u'C0DEED',
#    u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme1/bg.png',
#    u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme1/bg.png',
#    u'profile_background_tile': False,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/4178456249/1451731339',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/683237031552643072/FN01uim3_normal.png',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/683237031552643072/FN01uim3_normal.png',
#    u'profile_link_color': u'0084B4',
#    u'profile_sidebar_border_color': u'C0DEED',
#    u'profile_sidebar_fill_color': u'DDEEF6',
#    u'profile_text_color': u'333333',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'pzi_sports',
#    u'statuses_count': 13919,
#    u'time_zone': u'Pacific Time (US & Canada)',
#    u'translator_type': u'none',
#    u'url': None,
#    u'utc_offset': -25200,
#    u'verified': False}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Thu Oct 27 21:05:45 +0000 2016',
#   u'entities': {u'hashtags': [{u'indices': [96, 111],
#      u'text': u'ATHLETES4AIDAN'}],
#    u'symbols': [],
#    u'urls': [{u'display_url': u'twitter.com/i/web/status/7\u2026',
#      u'expanded_url': u'https://twitter.com/i/web/status/791747739445002240',
#      u'indices': [113, 136],
#      u'url': u'https://t.co/Znv85WvNFn'}],
#    u'user_mentions': [{u'id': 285265639,
#      u'id_str': u'285265639',
#      u'indices': [0, 16],
#      u'name': u'Adam Eaton',
#      u'screen_name': u'AdamSpankyEaton'},
#     {u'id': 3038570185,
#      u'id_str': u'3038570185',
#      u'indices': [40, 56],
#      u'name': u'Lil Warrior Aidan',
#      u'screen_name': u'lilwarrioraidan'}]},
#   u'favorite_count': 0,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 791747739445002240,
#   u'id_str': u'791747739445002240',
#   u'in_reply_to_screen_name': u'AdamSpankyEaton',
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': 285265639,
#   u'in_reply_to_user_id_str': u'285265639',
#   u'is_quote_status': True,
#   u'lang': u'en',
#   u'metadata': {u'iso_language_code': u'en', u'result_type': u'recent'},
#   u'place': None,
#   u'possibly_sensitive': False,
#   u'quoted_status': {u'contributors': None,
#    u'coordinates': None,
#    u'created_at': u'Thu Oct 27 19:43:26 +0000 2016',
#    u'entities': {u'hashtags': [],
#     u'symbols': [],
#     u'urls': [{u'display_url': u'twitter.com/whitesox/statu\u2026',
#       u'expanded_url': u'https://twitter.com/whitesox/status/791706687694483456',
#       u'indices': [44, 67],
#       u'url': u'https://t.co/bnP6zJo7ec'}],
#     u'user_mentions': [{u'id': 285265639,
#       u'id_str': u'285265639',
#       u'indices': [27, 43],
#       u'name': u'Adam Eaton',
#       u'screen_name': u'AdamSpankyEaton'}]},
#    u'favorite_count': 1,
#    u'favorited': False,
#    u'geo': None,
#    u'id': 791727024347947008,
#    u'id_str': u'791727024347947008',
#    u'in_reply_to_screen_name': None,
#    u'in_reply_to_status_id': None,
#    u'in_reply_to_status_id_str': None,
#    u'in_reply_to_user_id': None,
#    u'in_reply_to_user_id_str': None,
#    u'is_quote_status': True,
#    u'lang': u'en',
#    u'metadata': {u'iso_language_code': u'en', u'result_type': u'recent'},
#    u'place': {u'attributes': {},
#     u'bounding_box': {u'coordinates': [[[-87.799908, 41.733586],
#        [-87.740829, 41.733586],
#        [-87.740829, 41.757299],
#        [-87.799908, 41.757299]]],
#      u'type': u'Polygon'},
#     u'contained_within': [],
#     u'country': u'United States',
#     u'country_code': u'US',
#     u'full_name': u'Burbank, IL',
#     u'id': u'48f2609344f0c3f7',
#     u'name': u'Burbank',
#     u'place_type': u'city',
#     u'url': u'https://api.twitter.com/1.1/geo/id/48f2609344f0c3f7.json'},
#    u'possibly_sensitive': False,
#    u'quoted_status_id': 791706687694483456,
#    u'quoted_status_id_str': u'791706687694483456',
#    u'retweet_count': 0,
#    u'retweeted': False,
#    u'source': u'<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    u'text': u'Congratulations to our guy @AdamSpankyEaton https://t.co/bnP6zJo7ec',
#    u'truncated': False,
#    u'user': {u'contributors_enabled': False,
#     u'created_at': u'Fri Apr 17 22:57:36 +0000 2009',
#     u'default_profile': False,
#     u'default_profile_image': False,
#     u'description': u'Home of the http://t.co/WG2ZCl9ZHb  CJ Wilson Mazda Countryside,Lake Villa, Orland Park Il/ Ventura Ca 7083542700 / 8472457600 / 7084443200 / 8056442886',
#     u'entities': {u'description': {u'urls': [{u'display_url': u'ZoomZoomNation.com',
#         u'expanded_url': u'http://www.ZoomZoomNation.com',
#         u'indices': [12, 34],
#         u'url': u'http://t.co/WG2ZCl9ZHb'}]},
#      u'url': {u'urls': [{u'display_url': u'zoomzoomnation.com',
#         u'expanded_url': u'http://www.zoomzoomnation.com',
#         u'indices': [0, 22],
#         u'url': u'http://t.co/a7tw0oyp0y'}]}},
#     u'favourites_count': 4972,
#     u'follow_request_sent': None,
#     u'followers_count': 1865,
#     u'following': None,
#     u'friends_count': 375,
#     u'geo_enabled': True,
#     u'has_extended_profile': False,
#     u'id': 32642629,
#     u'id_str': u'32642629',
#     u'is_translation_enabled': False,
#     u'is_translator': False,
#     u'lang': u'en',
#     u'listed_count': 48,
#     u'location': u'Chicagoland / LA / Ventura',
#     u'name': u'CJ Wilson Mazda',
#     u'notifications': None,
#     u'profile_background_color': u'0099B9',
#     u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/378800000052384464/88e6a9463d891777de56da031347f83f.jpeg',
#     u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/378800000052384464/88e6a9463d891777de56da031347f83f.jpeg',
#     u'profile_background_tile': True,
#     u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/32642629/1413484742',
#     u'profile_image_url': u'http://pbs.twimg.com/profile_images/481854918043508736/Y4RC1U4R_normal.jpeg',
#     u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/481854918043508736/Y4RC1U4R_normal.jpeg',
#     u'profile_link_color': u'009AB9',
#     u'profile_sidebar_border_color': u'FFFFFF',
#     u'profile_sidebar_fill_color': u'95E8EC',
#     u'profile_text_color': u'3C3940',
#     u'profile_use_background_image': True,
#     u'protected': False,
#     u'screen_name': u'ZOOMZOOMNATION',
#     u'statuses_count': 4847,
#     u'time_zone': u'Central Time (US & Canada)',
#     u'translator_type': u'none',
#     u'url': u'http://t.co/a7tw0oyp0y',
#     u'utc_offset': -18000,
#     u'verified': False}},
#   u'quoted_status_id': 791727024347947008,
#   u'quoted_status_id_str': u'791727024347947008',
#   u'retweet_count': 0,
#   u'retweeted': False,
#   u'source': u'<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   u'text': u"@AdamSpankyEaton Join us! You're one of @lilwarrioraidan favorites! Be a SUPER SPORTS HERO!! \u2764\u2764 #ATHLETES4AIDAN\u2026 https://t.co/Znv85WvNFn",
#   u'truncated': True,
#   u'user': {u'contributors_enabled': False,
#    u'created_at': u'Mon Feb 23 22:14:13 +0000 2015',
#    u'default_profile': True,
#    u'default_profile_image': False,
#    u'description': u'I am a brave warrior fighting a BIG FIGHT! I have had tons of surgeries. I also have Autism. I love SPORTS, KYLE SCHWARBER & the Cubs! #ATHLETES4AIDAN',
#    u'entities': {u'description': {u'urls': []},
#     u'url': {u'urls': [{u'display_url': u'facebook.com/lilwarrioraida\u2026',
#        u'expanded_url': u'https://www.facebook.com/lilwarrioraidan/',
#        u'indices': [0, 23],
#        u'url': u'https://t.co/9a12JlIjqN'}]}},
#    u'favourites_count': 116,
#    u'follow_request_sent': None,
#    u'followers_count': 130,
#    u'following': None,
#    u'friends_count': 572,
#    u'geo_enabled': False,
#    u'has_extended_profile': False,
#    u'id': 3038570185,
#    u'id_str': u'3038570185',
#    u'is_translation_enabled': False,
#    u'is_translator': False,
#    u'lang': u'en',
#    u'listed_count': 0,
#    u'location': u'Chicago, IL',
#    u'name': u'Lil Warrior Aidan',
#    u'notifications': None,
#    u'profile_background_color': u'C0DEED',
#    u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme1/bg.png',
#    u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme1/bg.png',
#    u'profile_background_tile': False,
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/569984377988186112/k9UY1FI7_normal.jpeg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/569984377988186112/k9UY1FI7_normal.jpeg',
#    u'profile_link_color': u'0084B4',
#    u'profile_sidebar_border_color': u'C0DEED',
#    u'profile_sidebar_fill_color': u'DDEEF6',
#    u'profile_text_color': u'333333',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'lilwarrioraidan',
#    u'statuses_count': 81,
#    u'time_zone': None,
#    u'translator_type': u'none',
#    u'url': u'https://t.co/9a12JlIjqN',
#    u'utc_offset': None,
#    u'verified': False}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Thu Oct 27 21:05:44 +0000 2016',
#   u'entities': {u'hashtags': [],
#    u'symbols': [],
#    u'urls': [],
#    u'user_mentions': [{u'id': 59448491,
#      u'id_str': u'59448491',
#      u'indices': [0, 11],
#      u'name': u'Wrexham Council',
#      u'screen_name': u'wrexhamcbc'}]},
#   u'favorite_count': 0,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 791747732679471104,
#   u'id_str': u'791747732679471104',
#   u'in_reply_to_screen_name': u'wrexhamcbc',
#   u'in_reply_to_status_id': 791701187003285504,
#   u'in_reply_to_status_id_str': u'791701187003285504',
#   u'in_reply_to_user_id': 59448491,
#   u'in_reply_to_user_id_str': u'59448491',
#   u'is_quote_status': False,
#   u'lang': u'en',
#   u'metadata': {u'iso_language_code': u'en', u'result_type': u'recent'},
#   u'place': None,
#   u'retweet_count': 0,
#   u'retweeted': False,
#   u'source': u'<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   u'text': u"@wrexhamcbc that picture really doesn't look like a sports field.",
#   u'truncated': False,
#   u'user': {u'contributors_enabled': False,
#    u'created_at': u'Sun Feb 22 12:03:12 +0000 2009',
#    u'default_profile': False,
#    u'default_profile_image': False,
#    u'description': u'',
#    u'entities': {u'description': {u'urls': []}},
#    u'favourites_count': 78,
#    u'follow_request_sent': None,
#    u'followers_count': 141,
#    u'following': None,
#    u'friends_count': 503,
#    u'geo_enabled': True,
#    u'has_extended_profile': False,
#    u'id': 21561134,
#    u'id_str': u'21561134',
#    u'is_translation_enabled': False,
#    u'is_translator': False,
#    u'lang': u'en',
#    u'listed_count': 1,
#    u'location': u'Wrexham, UK',
#    u'name': u'Paul Morris',
#    u'notifications': None,
#    u'profile_background_color': u'020812',
#    u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/189910094/xdeb97b18b77558ca4c8de5e01d82733.jpg',
#    u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/189910094/xdeb97b18b77558ca4c8de5e01d82733.jpg',
#    u'profile_background_tile': False,
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/1209472013/100_0170_2_normal.jpg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/1209472013/100_0170_2_normal.jpg',
#    u'profile_link_color': u'2280A9',
#    u'profile_sidebar_border_color': u'2280A9',
#    u'profile_sidebar_fill_color': u'020812',
#    u'profile_text_color': u'17406C',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'pauljohnmorris',
#    u'statuses_count': 971,
#    u'time_zone': u'London',
#    u'translator_type': u'none',
#    u'url': None,
#    u'utc_offset': 3600,
#    u'verified': False}}]

# %%
tweets[0].keys()
# Out:
# [u'contributors',
#  u'truncated',
#  u'text',
#  u'is_quote_status',
#  u'in_reply_to_status_id',
#  u'id',
#  u'favorite_count',
#  u'entities',
#  u'retweeted',
#  u'coordinates',
#  u'source',
#  u'in_reply_to_screen_name',
#  u'in_reply_to_user_id',
#  u'retweet_count',
#  u'id_str',
#  u'favorited',
#  u'user',
#  u'geo',
#  u'in_reply_to_user_id_str',
#  u'possibly_sensitive',
#  u'lang',
#  u'created_at',
#  u'in_reply_to_status_id_str',
#  u'place',
#  u'extended_entities',
#  u'metadata']

# %%
tweets[0]
# Out:
# {u'contributors': None,
#  u'coordinates': None,
#  u'created_at': u'Tue Oct 25 06:17:33 +0000 2016',
#  u'entities': {u'hashtags': [{u'indices': [0, 7], u'text': u'Karate'},
#    {u'indices': [41, 51], u'text': u'Tokyo2020'}],
#   u'media': [{u'display_url': u'pic.twitter.com/BSoKz4P8v6',
#     u'expanded_url': u'https://twitter.com/FirstpostSports/status/790799441485713408/photo/1',
#     u'id': 790799249441038338L,
#     u'id_str': u'790799249441038338',
#     u'indices': [97, 120],
#     u'media_url': u'http://pbs.twimg.com/media/Cvl7uj-UIAIYJuw.jpg',
#     u'media_url_https': u'https://pbs.twimg.com/media/Cvl7uj-UIAIYJuw.jpg',
#     u'sizes': {u'large': {u'h': 630, u'resize': u'fit', u'w': 1200},
#      u'medium': {u'h': 630, u'resize': u'fit', u'w': 1200},
#      u'small': {u'h': 357, u'resize': u'fit', u'w': 680},
#      u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}},
#     u'type': u'photo',
#     u'url': u'https://t.co/BSoKz4P8v6'}],
#   u'symbols': [],
#   u'urls': [{u'display_url': u'bit.ly/2faR1vQ',
#     u'expanded_url': u'http://bit.ly/2faR1vQ',
#     u'indices': [73, 96],
#     u'url': u'https://t.co/pn9oFt0cqd'}],
#   u'user_mentions': [{u'id': 52422878,
#     u'id_str': u'52422878',
#     u'indices': [52, 61],
#     u'name': u'Olympics',
#     u'screen_name': u'Olympics'}]},
#  u'extended_entities': {u'media': [{u'display_url': u'pic.twitter.com/BSoKz4P8v6',
#     u'expanded_url': u'https://twitter.com/FirstpostSports/status/790799441485713408/photo/1',
#     u'id': 790799249441038338L,
#     u'id_str': u'790799249441038338',
#     u'indices': [97, 120],
#     u'media_url': u'http://pbs.twimg.com/media/Cvl7uj-UIAIYJuw.jpg',
#     u'media_url_https': u'https://pbs.twimg.com/media/Cvl7uj-UIAIYJuw.jpg',
#     u'sizes': {u'large': {u'h': 630, u'resize': u'fit', u'w': 1200},
#      u'medium': {u'h': 630, u'resize': u'fit', u'w': 1200},
#      u'small': {u'h': 357, u'resize': u'fit', u'w': 680},
#      u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}},
#     u'type': u'photo',
#     u'url': u'https://t.co/BSoKz4P8v6'}]},
#  u'favorite_count': 0,
#  u'favorited': False,
#  u'geo': None,
#  u'id': 790799441485713408L,
#  u'id_str': u'790799441485713408',
#  u'in_reply_to_screen_name': None,
#  u'in_reply_to_status_id': None,
#  u'in_reply_to_status_id_str': None,
#  u'in_reply_to_user_id': None,
#  u'in_reply_to_user_id_str': None,
#  u'is_quote_status': False,
#  u'lang': u'en',
#  u'metadata': {u'iso_language_code': u'en', u'result_type': u'recent'},
#  u'place': None,
#  u'possibly_sensitive': False,
#  u'retweet_count': 1,
#  u'retweeted': False,
#  u'source': u'<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#  u'text': u'#Karate to debut on the world stage with #Tokyo2020 @Olympics inclusion\n\nhttps://t.co/pn9oFt0cqd https://t.co/BSoKz4P8v6',
#  u'truncated': False,
#  u'user': {u'contributors_enabled': False,
#   u'created_at': u'Fri Jul 15 12:15:40 +0000 2011',
#   u'default_profile': False,
#   u'default_profile_image': False,
#   u'description': u'Bringing you live updates, breaking news, opinions and photos from the world of sport.',
#   u'entities': {u'description': {u'urls': []},
#    u'url': {u'urls': [{u'display_url': u'firstpost.com/category/sports',
#       u'expanded_url': u'http://www.firstpost.com/category/sports',
#       u'indices': [0, 22],
#       u'url': u'http://t.co/XSaFXN4DBr'}]}},
#   u'favourites_count': 46,
#   u'follow_request_sent': None,
#   u'followers_count': 141132,
#   u'following': None,
#   u'friends_count': 725,
#   u'geo_enabled': False,
#   u'has_extended_profile': False,
#   u'id': 335891957,
#   u'id_str': u'335891957',
#   u'is_translation_enabled': False,
#   u'is_translator': False,
#   u'lang': u'en',
#   u'listed_count': 506,
#   u'location': u'India',
#   u'name': u'FirstpostSports',
#   u'notifications': None,
#   u'profile_background_color': u'C0DEED',
#   u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/298954807/fp_twitter_bg_new.jpg',
#   u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/298954807/fp_twitter_bg_new.jpg',
#   u'profile_background_tile': False,
#   u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/335891957/1474036999',
#   u'profile_image_url': u'http://pbs.twimg.com/profile_images/2503138588/lc89nnbhz3tvpkztrxhe_normal.png',
#   u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/2503138588/lc89nnbhz3tvpkztrxhe_normal.png',
#   u'profile_link_color': u'0084B4',
#   u'profile_sidebar_border_color': u'FFFFFF',
#   u'profile_sidebar_fill_color': u'DDEEF6',
#   u'profile_text_color': u'333333',
#   u'profile_use_background_image': True,
#   u'protected': False,
#   u'screen_name': u'FirstpostSports',
#   u'statuses_count': 109494,
#   u'time_zone': u'New Delhi',
#   u'translator_type': u'none',
#   u'url': u'http://t.co/XSaFXN4DBr',
#   u'utc_offset': 19800,
#   u'verified': True}}

# %% [markdown]
# #### Get an accounts tweets

# %%
accounts = ["espn","foxsports","skepticalsports"]

# %%
acounts_tweets = []
for account in accounts:
    results=twitter.get_user_timeline(screen_name=account,cursor=-1,format="json")
    acounts_tweets.extend(results)

# %% [markdown]
# #### Get all tweets from an account from yesterday

# %%
def get_yesterday_tweets(handle):
    tweets=[]
    now=datetime.utcnow().date()
    today_date = datetime(now.year,now.month,now.day,0,0)
    yesterday_date = datetime(now.year,now.month,now.day-1,0,0)
    max_id=None
    while True:
        results=twitter.get_user_timeline(screen_name=handle,max_id=max_id,format="json")
        if len(results)>0:
            for result in results:
                tweet_date = datetime.strptime(result["created_at"],'%a %b %d %H:%M:%S +0000 %Y')
                if tweet_date < yesterday_date:
                    return tweets
                elif tweet_date < today_date:
                    tweets.append(result)
                    max_id = result["id_str"]

# %%
len(get_yesterday_tweets("skepticalsports"))
# Out:
# ---------------------------------------------------------------------------
# TwythonError                              Traceback (most recent call last)
# <ipython-input-15-525a6548d03a> in <module>()
# ----> 1 len(get_yesterday_tweets("skepticalsports"))
#
# <ipython-input-13-758413bfad07> in get_yesterday_tweets(handle)
#       6     max_id=None
#       7     while True:
# ----> 8         results=twitter.get_user_timeline(screen_name=handle,max_id=max_id,format="json")
#       9         if len(results)>0:
#      10             for result in results:
#
# /Users/curtisfocht/anaconda/lib/python2.7/site-packages/twython/endpoints.pyc in get_user_timeline(self, **params)
#      45
#      46         """
# ---> 47         return self.get('statuses/user_timeline', params=params)
#      48     get_user_timeline.iter_mode = 'id'
#      49
#
# /Users/curtisfocht/anaconda/lib/python2.7/site-packages/twython/api.pyc in get(self, endpoint, params, version)
#     262     def get(self, endpoint, params=None, version='1.1'):
#     263         """Shortcut for GET requests via :class:`request`"""
# --> 264         return self.request(endpoint, params=params, version=version)
#     265
#     266     def post(self, endpoint, params=None, version='1.1'):
#
# /Users/curtisfocht/anaconda/lib/python2.7/site-packages/twython/api.pyc in request(self, endpoint, method, params, version)
#     256
#     257         content = self._request(url, method=method, params=params,
# --> 258                                 api_call=url)
#     259
#     260         return content
#
# /Users/curtisfocht/anaconda/lib/python2.7/site-packages/twython/api.pyc in _request(self, url, method, params, api_call)
#     192                 error_message,
#     193                 error_code=response.status_code,
# --> 194                 retry_after=response.headers.get('X-Rate-Limit-Reset'))
#     195
#     196         try:
#
# TwythonError: Twitter API returned a 503 (Service Unavailable), Over capacity

# %% [markdown]
# #### Save tweets as json file

# %%
for account in accounts:
    with open(account + "_" + str(datetime.utcnow().date()) + ".json","w") as outfile:
        json.dump(get_yesterday_tweets(account),outfile)
